# %%
import matplotlib.pyplot as plt

Tau = [133.36, 270.43, 393.16, 531.15, 667.77]
Resid = [0.03089, 0.02825, 0.02695, 0.02798, 0.02969]

plt.scatter(Tau, Resid)
plt.title("Tau vs Residuals For Light Curve Fits")
plt.xlabel("Tau(sec)")
plt.ylabel("Residual")
plt.show()
